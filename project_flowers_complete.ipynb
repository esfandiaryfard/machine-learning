# %% [markdown]
# <a href="https://colab.research.google.com/github/esfandiaryfard/machine-learning/blob/main/project_flowers_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import os
from torchvision.datasets import ImageFolder
import torchvision.transforms as T
from torch.utils.data import DataLoader
from torchvision.io import read_image
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# # here we connect to drive

# %%
#we are connecting Google Drive and Google Colab
from google.colab import drive

# %%
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# here we unzip the file !unzip path_to_file.zip -d path_to_directory

# %%
# !unzip "/content/drive/MyDrive/Work1/database/db_flowers/db_flowers.zip" -d "/content/drive/MyDrive/Work1/database/db_folder/"
# Out:
# Archive:  /content/drive/MyDrive/Work1/database/db_flowers/db_flowers.zip
# replace /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/100080576_f52e8ee070_n.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/100080576_f52e8ee070_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10140303196_b88d3d6cec.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10172379554_b296050f82_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10172567486_2748826a8b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10172636503_21bededa75_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/102841525_bd6628ae3c.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10300722094_28fa978807_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1031799732_e7f4008c03.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10391248763_1d16681106_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10437754174_22ec990b77_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10437770546_8bb6f7bdd3_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10437929963_bc13eebe0c.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10466290366_cc72e33532.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10466558316_a7198b87e2.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10555749515_13a12a026e.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10555815624_dc211569b0.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10555826524_423eb8bf71_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10559679065_50d2b16f6d.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/105806915_a9c13e2106_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10712722853_5632165b04.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/107592979_aaa9cdfe78_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10770585085_4742b9dac3_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10841136265_af473efc60.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10993710036_2033222c91.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10993818044_4c19b86c82.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/10994032453_ac7f8d9e2e.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11023214096_b5b39fab08.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11023272144_fce94401f2_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11023277956_8980d53169_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11124324295_503f3a0804.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1140299375_3aa7024466.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11439894966_dca877f0cd.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1150395827_6f94a5c6e4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11642632_1e7627a2cc.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11834945233_a53b7a92ac_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11870378973_2ec1919f12.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/11891885265_ccefec7284_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/12193032636_b50ae7db35_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/12348343085_d4c396e5b5_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/12585131704_0f64b17059_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/12601254324_3cb62c254a_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1265350143_6e2b276ec9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/12701063955_4840594ea6_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1285423653_18926dc2c8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1286274236_1d7ac84efb_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/12891819633_e4c82b51e8.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1299501272_59d9da5510_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1306119996_ab8ae14d72_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1314069875_da8dc023c6_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1342002397_9503c97b49.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/134409839_71069a95d1_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1344985627_c3115e2d71_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/13491959645_2cd9df44d6_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1354396826_2868631432_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1355787476_32e9f2a30b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/13583238844_573df2de8e_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1374193928_a52320eafa.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/13826249325_f61cb15f86_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/13901930939_a7733c03f0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1392131677_116ec04751.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1392946544_115acbb2d9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/13953307149_f8de6a768c_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1396526833_fb867165be_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/13977181862_f8237b6b52.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14021430525_e06baf93a9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14073784469_ffb12f3387_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14087947408_9779257411_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14088053307_1a13a0bf91_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14114116486_0bb6649bc1_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14147016029_8d3cf2414e.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14163875973_467224aaf5_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14167534527_781ceb1b7a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14167543177_cd36b54ac6_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14219214466_3ca6104eae_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14221836990_90374e6b34.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14221848160_7f0a37c395.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14245834619_153624f836.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14264136211_9531fbc144.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14272874304_47c0a46f5a.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14307766919_fac3c37a6b_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14330343061_99478302d4_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14332947164_9b13513c71_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14333681205_a07c9f1752_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14350958832_29bdd3a254.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14354051035_1037b30421_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14372713423_61e2daae88.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14399435971_ea5868c792.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14402451388_56545a374a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/144076848_57e1d662e3_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/144099102_bf63a41e4f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1441939151_b271408c8d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14421389519_d5fd353eb4.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/144603918_b9de002f60_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14471433500_cdaa22e3ea_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14485782498_fb342ec301.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14507818175_05219b051c_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14523675369_97c31d0b5b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14551098743_2842e7a004_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14554906452_35f066ffe9_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14564545365_1f1d267bf1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14569895116_32f0dcb0f9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14591326135_930703dbed_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14600779226_7bbc288d40_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14613443462_d4ed356201.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14621687774_ec52811acd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14674743211_f68b13f6d9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14698531521_0c2f0c6539.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/147068564_32bb4350cc.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14707111433_cce08ee007.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14716799982_ed6d626a66.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14816364517_2423021484_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14866200659_6462c723cb_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14907815010_bff495449f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/14921511479_7b0a647795.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15029936576_8d6f96c72c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15100730728_a450c5f422_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15207766_fc2f1d692c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15306268004_4680ba95e1.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/153210866_03cc9f2f36.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15327813273_06cdf42210.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/154332674_453cea64f4.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15760153042_a2a90e9da5_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15760811380_4d686c892b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15784493690_b1858cdb2b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15813862117_dedcd1c56f_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/15853110333_229c439e7f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/158869618_f1a6704236_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16020253176_60f2a6a5ca_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16025261368_911703a536_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16056178001_bebc2153fe_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16121105382_b96251e506_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16161045294_70c76ce846_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/162362896_99c7d851c8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/162362897_1d21b70621_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16291797949_a1b1b7c2bd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16323838000_3818bce5c6_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16360180712_b72695928c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/163978992_8128b49d3e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16401288243_36112bd52f_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16482676953_5296227d40_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16492248512_61a57dfec1_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16527403771_2391f137c4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16577886423_9b23622f1d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16737503507_431768a927.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16819071290_471d99e166_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/16833748795_b681b2839f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/169371301_d9b91a2a42.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/17027891179_3edc08f4f6.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/17101762155_2577a28395.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/171972704_389cf7a953.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/17249393016_093e915012_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/172882635_4cc7b86731_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/17357636476_1953c07aa4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/174131220_c853df1287.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/175106495_53ebdef092_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/176375506_201859bb92_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/17821980772_35164ae1e8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18023717391_e2c9089e10.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/181007802_7cab5ee78e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18195689904_46619b7e16_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18203367608_07a04e98a4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18354545086_693ea7bc2a.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18400014056_2e4c601ed5.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18442919723_d1251d3e14_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18474740346_ffdaa18032.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18582579815_4c6637e9ff_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18622672908_eab6dc9140_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18635898912_eb8e058ef0.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18679421522_3be9879e32.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18684594849_7dd3634f5e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18711159980_11d3bd5042.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1879567877_8ed2a5faa7_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/18901817451_43e2b45f6c.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19019544592_b64469bf84_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19177263840_6a316ea639.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19178753159_a471bf4b6b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19280272025_57de24e940_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19527362416_8bdcbefb8b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19544831049_0d738d4872_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/1955336401_fbb206d6ef_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19653086178_28156b7ce4_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19813618946_93818db7aa_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19834392829_7d697871f6.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19865728236_a62f8f445b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/19975899671_ebc42b7865_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2001380507_19488ff96a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20182559506_40a112f762.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2019064575_7656b9340f_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20289938802_e16fa9f23d.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20329326505_a777c71cc2.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2045022175_ad087f5f60_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2057816617_18448093d0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20580471306_ab5a011b15_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20619292635_9857a12d54.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20685027271_0e7306e7c1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20703737132_179560d0fb.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20773528301_008fcbc5a1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2077865117_9ed85191ae_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2087343668_ef4fb95787_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/20948886919_cac7844f34_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/21402054779_759366efb0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/21626652132_97e1318bb8_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/21652746_cc379e0eea_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/21805938544_bf6bb0e4bc.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2213954589_c7da4b1486.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/22244161124_53e457bb66_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/22873310415_3a5674ec10_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/23095658544_7226386954_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2331133004_582772d58f_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2346726545_2ebce2b2a6.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2349640101_212c275aa7.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2365428551_39f83f10bf_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2408024540_37f0be7cc0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2454280135_ac3aa75cdc_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2454280137_e1637536ae_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2473825306_62fd5f8785_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2476937534_21b285aa46_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2479956481_8d1a9699be_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2480569557_f4e1f0dcb8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2481823240_eab0d86921.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2482982436_a2145359e0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2488902131_3417698611_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2498632196_e47a472d5a.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2509545845_99e79cb8a2_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2511306240_9047015f2d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2513618768_ff7c004796_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2514748602_343d4727c0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2520369272_1dcdb5a892_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2521408074_e6f86daf21_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/25360380_1a881a5648.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2536529152_33ef3ee078_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2538504987_fe524b92a8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2539552964_921cf645ba_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2561352120_7961d8263f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2561371688_c80a4fe957_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2567033807_8e918c53d8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2573240560_ff7ffdd449.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2578695910_5ab8ee17c1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2579018590_74359dcf1a_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2581171297_b0a249b92b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2590291468_2635d3e4e0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2599662355_7782218c83.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2607132536_d95198e619_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2611119198_9d46b94392.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2612704455_efce1c2144_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2617111535_54c2ac8462.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2619413565_61a6cd3ac9_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2621723097_736febb4a4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2627815904_919373e7f5.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2632216904_274aa17433.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2635314490_e12d3b0f36_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2641979584_2b21c3fe29_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2642408410_61545fdc83_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2646438199_b309cffd65_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2649404904_b7a91991bb_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2666572212_2caca8de9f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2713919471_301fcc941f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/27400851831_fe08fbcb66_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/28056118836_77a6847d94_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2812442552_3eed5fb9f2_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2828733818_1c1ed0089d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2838487505_6c3b48efa5_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2862944799_45bc8e7302.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/286875003_f7c0e1882d.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2877860110_a842f8b14a_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2889325612_f2fc403ff0_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2901376034_cdb4bac26b_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/2908212142_5437fa67ff_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/29380234244_c50a60374e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/294451721_5106537b34.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/29821115270_eccd3866e1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/299129811_d6ebda9970.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/30001711132_eb0fd7b04c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/301964511_fab84ea1c1.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3025866885_22fb0b61c6_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/302782756_d35cb3e468.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/305160642_53cde0f44f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3080880039_4f1bd592e5_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3084924076_4d5c5711af_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3098641292_76c908ba1f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3117644024_1cbb59a509_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3196066025_d187108070_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3275951182_d27921af97_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3285641623_da0e47f49a.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3310644753_5607eb96a4_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3326037909_b5ae370722_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3336704121_cfeb67a7d7.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3337536080_1db19964fe.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3337643329_accc9b5426.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3338077096_3a8ed0e2bc_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3356112863_75da8bca2c_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3379332157_04724f6480.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33802431204_7c58f4e21b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33806101464_5eca772954_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33807950584_f5b63715e4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33809174824_00ba798039_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33809956124_b49dcddf8f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33810542134_a493f19a71_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33814092924_b23d019011_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33819069114_6ecc240b54_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33822751084_c83a7abffd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33830843653_ee6d7989fa_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33836936163_2dce95ee4d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33837577463_1ae52a3726_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33838292353_8b143f7980_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33839388103_79cb79f7bc_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33843240613_0b736f9896_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33843400403_db00aa16b8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33849854704_d2a2415e4d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33855966243_01b2486428_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33857335804_7f0c96243b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33858238653_6549e21f53_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33859244503_eeeca6a397_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33863293993_3ed7515936_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3386988684_bc5a66005e.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33871813063_d7b6bedafe_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33872893913_72d64a9b85_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33874126263_3f6f965784_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33879354664_615c72773d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33880234094_2541c9c83d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33884228533_91b75ff4d4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33885735373_444ba02d9c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33887503434_a2762228f4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33891398493_e0b6d7f683_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33891703033_822f7810ce_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33901756843_94e198d40e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33911247013_82a1acfcea_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33918001783_06a692e371_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/33923454163_9cabcaa733_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34076975155_1faeedec90_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3410906335_37e8a24b1c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3415180846_d7b5cced14_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34261196280_aa99186136_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34266042310_9c1abd8e11_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34266044490_01dacd2ac2_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34275152390_44e7262261_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34275662120_7757a15d07_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34276373070_27ec2d2596_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34283602490_b61f3da99d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34283646340_4fe48d1bb7_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34287492780_6dab677857_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34288158610_6e42406193_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34289553800_606f1f2954_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34293312980_5f6c492c52_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34293871550_71d1e4d482_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34295444880_b4376b3a8b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34300874850_923cc2881c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34310869690_56cdc84a17_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34312496620_bc01a98aeb_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34326606950_41ff8997d7_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34326847400_f4de801005_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34337108550_0b619aa726_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34342014230_4230ae8e08_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3440366251_5b9bdf27c9_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34476770012_38fba290f3_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34486116262_411e6991f4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34508227161_a9ff840f71_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3450822975_7e77d67636_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34510103621_250ee7ae64_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34517409722_829ec7e152_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34518066912_0e432507bc_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34518374242_310e7abd54_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34520690871_8fe693bc71_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34520699571_f880744f46_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34522174462_b7cbee3ecb_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34524074031_e42b9b1acd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34524085651_1f0b7e9497_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34530932101_957fab3650_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34531542152_c8ba2e0fea_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34532930772_5cc5fc600d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34539556222_f7ba32f704_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34540113401_b81594e92a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34540176411_a35a19a8ef_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34542837641_10492bf600_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34543119581_1fb7e0bd7f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34546791291_eb8e15e18a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34546994701_a000b283f1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34547261352_d39bf4073a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34554334542_7d8f68a75c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34562146951_cf3d2a627c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3456403987_5bd5fa6ece_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34566613262_fefbcc279a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34571214621_f655295459_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34585331601_837dbe5254_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34585995071_13e07140d8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34590677231_0ed33ccd55_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34591991761_16fc5c9c00_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34602180741_cf2f671ba5_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34611565966_9de274f987_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34613530216_26cf037012_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3463313493_9497aa47e5_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34637394046_f85541735d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34637970155_a2b917077c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34638378196_216d5bbc2e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34643914016_2e659d6e82_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34652819496_0b6f758986_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34658035045_7782e95b50_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34661399476_9ea7e2fd53_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34664107325_701d5c6f08_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34665595995_13f76d5b60_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34670512115_af22cce24d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34682895116_88ef018e83_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3468498624_d082f99e98.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34693373736_9ce6d9e1c3_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34695914906_961f92ffcd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34696729796_190b1dfdf1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34696730126_056ffea63c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34696730346_5f0c131e59_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34701078235_4a770d14a1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34701198765_54aa641d7a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34718882165_68cdc9def9_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34720703615_bdf1335d8b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34727863665_b00ac77266_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34729724865_787c98299d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/34733243845_29f1c30634_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3474942718_c418dae6f1.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3475870145_685a19116d.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3483303007_42e3f90da7.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3491933306_43cfe2cfbe.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3494265422_9dba8f2191_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3504430338_77d6a7fab4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3506866918_61dd5fc53b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3533954656_79156c8473.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3546455114_cd2dea5e02.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3552074420_2a0a7166db_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3588872598_e0f9a1d2a1_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3598615130_578ed30e5f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3611577717_f3a7a8c416_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3625257860_33efeef614_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3627678863_557552c879_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3628485766_4ff937954a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3633489595_a037a9b7a4_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3637428148_a1dcccafa9_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3639009391_0f910681b7.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3640845041_80a92c4205_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3661613900_b15ca1d35d_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/367020749_3c9a652d75.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3695826945_9f374e8a00_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3699235066_fc09a02dfe_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3703643767_dee82cdef9_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3704305945_a80e60e2f6_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3704306975_75b74497d8.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3706420943_66f3214862_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3711723108_65247a3170.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3711892138_b8c953fdc1_z.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3713290261_8a66de23ab.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3717746329_53f515c6a6_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3720632920_93cf1cc7f3_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3750250718_eb61146c5f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3750771898_cfd50090ba_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3758221664_b19116d61f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3764116502_f394428ee0_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3773181799_5def396456.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3780380240_ef9ec1b737_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/daisy/3848258315_ed2fde4fb4.jpg
# ...
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166606598_5d2cd307c3_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166612682_711e680027_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166614014_5f0f8d715b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166616072_1233051d98_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166618384_850905fc63_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166620850_8a37b95972_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166623602_256179ab00_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166626128_8e0983ac8e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166632158_666116d770_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166635566_ee240b5408_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166640338_46b15d9ec8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166644048_b00a14f01b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166644048_b00a14f01b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7166646966_41d83cd703.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7177682195_c29265748d_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7179796338_05e8b1c87b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7205145492_baec4dbb94.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7205698252_b972087cc2.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7247182064_f8d6759446_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7266196114_c2a736a15a_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7342871880_c17fe0eb4f_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/738207467_fc59cfcd9b_z.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7447655334_e8f805ab95_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7448453762_aea8739f1b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7481204112_e3c57dd40a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7481215720_73e40f178f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7481217920_6f65766a1c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7775145448_c42e638a6a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/779359602_30abcbf5bb_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/7806320016_fcddfc1f8f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8394186551_28eed83a94_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8454707381_453b4862eb_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8454719295_4276c0e9c5_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8484905084_6a18c62b13_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8511683706_4173683d45_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8520482921_21dd204ebd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8520488975_a50d377f91.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8521597402_4b6169ba05.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8523133474_d2c0845b54.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8554190977_37ac747799_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8555123165_2fe57eff4f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8562853756_73778dac25_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8572847041_d0cc07861f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8585101979_4398146bf1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8585102511_fc452e6700_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8585102913_d80d3e2ff7_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8585103457_d64697c3cf_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8586204750_2891bd2ec9_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8586205168_8294e67195_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8586205446_8953a6c70e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8586205946_cda045f3f8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8601596054_33e40c2a7a.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8603340662_0779bd87fd.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8605564823_7a59d3d92a.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8614237582_74417799f4_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8619064872_dea79a9eb9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8622237974_b362574785_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8623170936_83f4152431.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8623173256_3f0eb4c506.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8628453641_6f87755815_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8659691170_09db83d023.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8668973377_c69527db42_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8668974855_8389ecbdca_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8669794378_97dda6036f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8673412732_f8fd690ee4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8673416166_620fc18e2f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8673416556_639f5c88f1_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8677713853_1312f65e71.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8681825637_837a63513a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8686013485_3c4dfbfd1f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8686332852_c6dcb2e86b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8687675254_c93f50d8b0_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8688502760_1c8d6de921_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8689672277_b289909f97_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8690789564_394eb04982_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8690791226_b1f015259f_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8695367666_0809529eaf_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8695372372_302135aeb2.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8697784345_e75913d220.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8702982836_75222725d7.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8706523526_a0f161b72b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8708209606_d3aede4801.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8708856019_f3be2353a4_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8710148289_6fc196a0f8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8711277462_b43df5454b_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712230357_1298b8513b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712243901_54d686319e_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712244311_da8e90bf8e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712260079_c0ff42e0e2_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712263493_3db76c5f82.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712266605_3787e346cd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712267391_c756f18ee7_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712267813_f7a9be2ec5.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712268519_f4c2c39a06_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712269349_2b933da2b8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712270243_8512cf4fbd.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712270665_57b5bda0a2_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8712282563_3819afb7bc.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713357842_9964a93473_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713387500_6a9138b41b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713388322_e5ae26263b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713389178_66bceb71a8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713390684_041148dd3e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713391394_4b679ea1e3_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713392604_90631fb809_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713394070_b24561b0a9.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713396140_5af8136136.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713397358_0505cc0176_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713397694_bcbcbba2c2_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713398114_bc96f1b624_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713398614_88202e452e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713398906_28e59a225a_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8713407768_f880df361f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8717900362_2aa508e9e5.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8722514702_7ecc68691c.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8723767533_9145dec4bd_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8729501081_b993185542_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8733586143_3139db6e9e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8748266132_5298a91dcf_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8750288831_5e49a9f29b.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8757486380_90952c5377.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8758464923_75a5ffe320_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8758519201_16e8d2d781_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8759594528_2534c0ec65_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8759597778_7fca5d434b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8759601388_36e2a50d98_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8759606166_8e475013fa_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8759618746_f5e39fdbf8_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8762189906_8223cef62f.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8762193202_0fbf2f6a81.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8768645961_8f1e097170_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8817622133_a42bb90e38_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8838347159_746d14e6c1_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8838354855_c474fc66a3_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8838914676_8ef4db7f50_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8838975946_f54194894e_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8838983024_5c1a767878_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8892851067_79242a7362_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8904780994_8867d64155_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8908062479_449200a1b4.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/8908097235_c3e746d36e_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9019694597_2d3bbedb17.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9030467406_05e93ff171_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9048307967_40a164a459_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/924782410_94ed7913ca_m.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9378657435_89fabf13c9_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9444202147_405290415b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9446982168_06c4d71da3_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9831362123_5aac525a99_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9870557734_88eb3b9e3b_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9947374414_fdf1d0861c_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9947385346_3a8cacea02_n.jpg
#   inflating: /content/drive/MyDrive/Work1/database/db_folder/flowers/tulip/9976515506_d496c5e72c.jpg

# %%
root_dir = "/content/drive/MyDrive/Work1/database/db_folder/flowers"
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders
input_folder = "/content/drive/MyDrive/Work1/database/db_folder/flowers/"

# %% [markdown]
# **we create a new folder with training, validation, test with a percentage of 0.7 /0.2 /0.1**

# %%
splitfolders.ratio(input_folder, output='/content/drive/MyDrive/Work1/output_flower',seed= 123, ratio=(.7,.2,.1),group_prefix=None)
# Out:
# Copying files: 4317 files [17:43,  4.06 files/s]

# %%
dir= "/content/drive/MyDrive/Work1/output_flower/"  
drive.mount("/content/drive",force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Import Torch
import torch
# Setup device
dev = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(dev)
# Out:
# cpu

# %% [markdown]
# **apply some transformations**

# %%
from torchvision.transforms.transforms import Resize
from torchvision import transforms

# Compose transformations
data_transform = transforms.Compose([
  transforms.Resize(224),
  transforms.CenterCrop(224),
  transforms.RandomHorizontalFlip(),
  transforms.RandomVerticalFlip(),
  transforms.ToTensor(),
])

# %% [markdown]
# **now we split our dataset in  3 folders: train, validation and test**

# %%
# Instantiate datasets
train_set = ImageFolder(os.path.join(dir, "train"), transform=data_transform)  
val_set = ImageFolder(os.path.join(dir, "val"), transform=data_transform)
test_set = ImageFolder(os.path.join(dir, "test"), transform=data_transform)

# %%
# Get number of classes (we'll need it in the model)
num_classes = len(train_set.classes)
# Print dataset statistics
print(f"Num. classes: {num_classes}")
print(f"Classes:\n {train_set.classes}")
print(f"Num. train samples: {len(train_set)}")
print(f"Num. valid. samples: {len(val_set)}")
print(f"Num. test samples: {len(test_set)}")
# Out:
# Num. classes: 5
# Classes:
#  ['daisy', 'dandelion', 'rose', 'sunflower', 'tulip']
# Num. train samples: 3019
# Num. valid. samples: 860
# Num. test samples: 438

# %%
img_x, label_x = train_set[600]
print(img_x,label_x)
# Out:
# tensor([[[0.2745, 0.2784, 0.2784,  ..., 0.4902, 0.4902, 0.4902],
#          [0.2706, 0.2745, 0.2784,  ..., 0.5020, 0.5020, 0.5020],
#          [0.2745, 0.2784, 0.2824,  ..., 0.5059, 0.5020, 0.5020],
#          ...,
#          [0.3216, 0.3216, 0.3255,  ..., 0.5804, 0.4902, 0.4667],
#          [0.3255, 0.3255, 0.3216,  ..., 0.7647, 0.5412, 0.4980],
#          [0.3176, 0.3255, 0.3216,  ..., 0.9451, 0.7176, 0.5373]],
#
#         [[0.5137, 0.5176, 0.5176,  ..., 0.7216, 0.7216, 0.7216],
#          [0.5098, 0.5137, 0.5176,  ..., 0.7333, 0.7333, 0.7333],
#          [0.5137, 0.5176, 0.5216,  ..., 0.7373, 0.7333, 0.7333],
#          ...,
#          [0.5647, 0.5647, 0.5686,  ..., 0.7608, 0.7098, 0.7098],
#          [0.5686, 0.5686, 0.5647,  ..., 0.8627, 0.7020, 0.7255],
#          [0.5725, 0.5686, 0.5647,  ..., 0.9765, 0.8039, 0.7176]],
#
#         [[0.7294, 0.7333, 0.7333,  ..., 0.9412, 0.9412, 0.9412],
#          [0.7255, 0.7294, 0.7333,  ..., 0.9529, 0.9529, 0.9529],
#          [0.7294, 0.7333, 0.7373,  ..., 0.9569, 0.9529, 0.9529],
#          ...,
#          [0.7882, 0.7882, 0.8000,  ..., 0.9020, 0.8863, 0.9059],
#          [0.7922, 0.7922, 0.7961,  ..., 0.9490, 0.8353, 0.9098],
#          [0.7922, 0.7922, 0.7961,  ..., 0.9882, 0.8902, 0.8667]]]) 1

# %%
train_set
# Out:
# Dataset ImageFolder
#     Number of datapoints: 3019
#     Root location: /content/drive/MyDrive/Work1/output_flower/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=224, interpolation=bilinear, max_size=None, antialias=None)
#                CenterCrop(size=(224, 224))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ToTensor()
#            )

# %% [markdown]
# **expample of one of the images belong to the validation set**

# %%
#img = read_image("/content/output/val/astilbe/1033455028_f0c6518ec9_c.jpg")
#plt.imshow(img.permute(2, 1, 0))

def show_example(img, label):
    print('Label: ', train_set.classes[label], "("+str(label)+")")
    plt.imshow(img.permute(1,2,0))

# %%
show_example(*val_set[100])
# Out:
# Label:  daisy (0)

# %% [markdown]
# **create a data loader instance with each dataset with a batch size of 32 and shuffling**

# %%
train_loader = DataLoader(train_set, batch_size=16, shuffle=True, drop_last=True, num_workers=2)
validation_loader = DataLoader(val_set, batch_size=16, shuffle=True, drop_last=False, num_workers=2)
test_loader = DataLoader(test_set, batch_size=16, shuffle=False, drop_last=False, num_workers=2)

#Notes:
# more is the number of workers, quicker will be with a saturage of the memory faster
#num_workers equal 0 means that it’s the main process that will do the data loading when needed
# num_workers equal 1 is the same as any n, but you’ll only have a single worker, so it might be slow

# %%
inputs, labels = next(iter(train_loader))
print(inputs.shape)   # the first value represents the value of the batch size
print(labels.shape)
# Out:
# torch.Size([16, 3, 224, 224])
# torch.Size([16])

# %% [markdown]
# **Creating a CNN model**

# %% [markdown]
# The minimal layers we need for defining a CNN are:
#
# Convolutional layer:
#
# nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, dilation)
#
# Non-linear layer:
#
# nn.ReLU()
#
# Max pooling:
#
# nn.MaxPool2d(kernel_size, stride)

# %%
import torch.nn as nn

class SimpleCNN(nn.Module):

  #Constructor
  def __init__(self):
    # Call parent contructor
    super().__init__()
    self.conv_layer = nn.Sequential(  #Sequential defines a block
        # Layer 1
        nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, padding=1, stride=2),
        nn.ReLU(),
        nn.BatchNorm2d(8),

        # Layer 2
        nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.MaxPool2d(kernel_size=2, stride=2),

       

         # Layer 3
        nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        nn.MaxPool2d(kernel_size=2, stride=2),

         #layer 4

        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(64),
        nn.MaxPool2d(kernel_size=2, stride=2),

          #layer 5

        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(128),
        nn.MaxPool2d(kernel_size=2, stride=2)

          #layer 6

       # nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=0, stride=1),
       # nn.ReLU(),
       # nn.BatchNorm2d(256),
       # nn.MaxPool2d(kernel_size=2, stride=2)

    )
  

# Forward
  def forward(self, x):
    x = self.conv_layer(x)
    return x

# %%
# Create the model
model = SimpleCNN()
print(model)
# Out:
# SimpleCNN(
#   (conv_layer): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (8): ReLU()
#     (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (16): ReLU()
#     (17): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
# )

# %% [markdown]
# The main difficulty in choosing CNN parameters is to compute the size of the first fully-connected layer, which depends on the number of features maps and the size of each feature map at the last convolutional layer, which depend on the kernel sizes, padding, strides, dilations of all convolutional layers.
#
# The simplest thing to do is to add the convolutional layers first, see the output size, and then add the fully-connected layers

# %%
# Get an element from the dataset
test_x, _ = test_set[0] # each element of the dataset is a couple (image, label)

# %%
# Get the size of a sample
test_x.size()
# Out:
# torch.Size([3, 224, 224])

# %% [markdown]
# Our 2D CNN model expects as input a tensor of shape: [N, C, H, W], where:
#
# - N is the number of samples (batch_size);
# - C is the number of channels (1 for grayscale images, 3 for RGB images);
# - H and W are height and width dimension of the images;
# We have to add the batch dimension to test_x

# %%
test_x = test_x.unsqueeze(dim=0) 
test_x.size()
# Out:
# torch.Size([1, 3, 224, 224])

# %%
output = model(test_x)
output.shape
output.size()
# Out:
# torch.Size([1, 128, 5, 5])

# %%
out_features = output.size(1) * output.size(2) * output.size(3)
print(out_features)
# Out:
# 3200

# %% [markdown]
# Now we can add some fully connected layers to our CNN model

# %%
class CNN(nn.Module):
  #Constructor
  def __init__(self):
    # Call parent contructor
    super().__init__()
    self.conv_layer = nn.Sequential(
         # Layer 1
        nn.Conv2d(in_channels=3, out_channels=8, kernel_size=3, padding=1, stride=2),
        nn.ReLU(),
        nn.BatchNorm2d(8),

        # Layer 2
        nn.Conv2d(in_channels=8, out_channels=16, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.MaxPool2d(kernel_size=2, stride=2),

       

         # Layer 3
        nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(32),
        nn.MaxPool2d(kernel_size=2, stride=2),

         #layer 4

        nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(64),
        nn.MaxPool2d(kernel_size=2, stride=2),

          #layer 5

        nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=0, stride=1),
        nn.ReLU(),
        nn.BatchNorm2d(128),
        nn.MaxPool2d(kernel_size=2, stride=2)

          #layer 6

       # nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=0, stride=1),
       # nn.ReLU(),
       # nn.BatchNorm2d(256),
       # nn.MaxPool2d(kernel_size=2, stride=2)

  

    )
    # Create fully-connected layers
    self.fc_layers = nn.Sequential(
        # a first FC layer
        nn.Linear(3200, 4096),
        nn.ReLU(),
        nn.Linear(4096, 1024),
        nn.ReLU(),
        # the final Classification Layer
        nn.Linear(1024, 5)
    )

  # Forward
  def forward(self, x):
    x = self.conv_layer(x) # x has size: [B,256,4,4]; before passing to fc layer, we have to flatten x
    x = x.view(x.size(0), -1) # now x has size [B, 4096]
    output = self.fc_layers(x) # [B, 4096] --> [B, 1024] --> [B, 10]
    return output

# %%
# Create the model
model = CNN()
output = model(test_x)
output.shape
# Out:
# torch.Size([1, 5])

# %% [markdown]
# We can train our model faster using the GPU (when it is available)

# %%
torch.cuda.is_available()
# Out:
# False

# %%
# Define an optimizier
import torch.optim as optim
optimizer = optim.SGD(model.parameters(), lr = 0.01)  
# Define a loss 
criterion = nn.CrossEntropyLoss()

# %%
def train(net, loaders, optimizer, criterion, epochs=100, dev=torch.device('cpu')):
    try:
        net = net.to(dev)
        print(net)
        # Initialize history
        history_loss = {"train": [], "val": [], "test": []}
        history_accuracy = {"train": [], "val": [], "test": []}
        # Process each epoch
        for epoch in range(epochs):
            # Initialize epoch variables
            sum_loss = {"train": 0, "val": 0, "test": 0}
            sum_accuracy = {"train": 0, "val": 0, "test": 0}
            # Process each split
            for split in ["train", "val", "test"]:
                if split == "train":
                  net.train()
                else:




                  net.eval()
                # Process each batch
                for (input, labels) in tqdm(loaders[split],desc=split):
                    # Move to CUDA
                    input = input.to(dev)
                    labels = labels.to(dev)
                    # Reset gradients
                    optimizer.zero_grad()
                    # Compute output
                    pred = net(input)
                    loss = criterion(pred, labels)
                    # Update loss
                    sum_loss[split] += loss.item()
                    # Check parameter update
                    if split == "train":
                        # Compute gradients
                        loss.backward()
                        # Optimize
                        optimizer.step()
                    # Compute accuracy
                    _,pred_labels = pred.max(1)
                    batch_accuracy = (pred_labels == labels).sum().item()/input.size(0)
                    # Update accuracy
                    sum_accuracy[split] += batch_accuracy
            # Compute epoch loss/accuracy
            epoch_loss = {split: sum_loss[split]/len(loaders[split]) for split in ["train", "val", "test"]}
            epoch_accuracy = {split: sum_accuracy[split]/len(loaders[split]) for split in ["train", "val", "test"]}
            # Update history
            for split in ["train", "val", "test"]:
                history_loss[split].append(epoch_loss[split])
                history_accuracy[split].append(epoch_accuracy[split])
            # Print info
            print(f"Epoch {epoch+1}:",
                  f"TrL={epoch_loss['train']:.4f},",
                  f"TrA={epoch_accuracy['train']:.4f},",
                  f"VL={epoch_loss['val']:.4f},",
                  f"VA={epoch_accuracy['val']:.4f},",
                  f"TeL={epoch_loss['test']:.4f},",
                  f"TeA={epoch_accuracy['test']:.4f},")
    except KeyboardInterrupt:
        print("Interrupted")
    finally:
        # Plot loss
        plt.title("Loss")
        for split in ["train", "val", "test"]:
            plt.plot(history_loss[split], label=split)
        plt.legend()
        plt.show()
        # Plot accuracy
        plt.title("Accuracy")
        for split in ["train", "val", "test"]:
            plt.plot(history_accuracy[split], label=split)
        plt.legend()
        plt.show()

# %%
# Define dictionary of loaders
loaders = {"train": train_loader,   
           "val": validation_loader,
           "test": test_loader}

# %%
# Train model
train(model, loaders, optimizer, criterion, epochs=25-+, dev=dev)
# Out:
# CNN(
#   (conv_layer): Sequential(
#     (0): Conv2d(3, 8, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): BatchNorm2d(8, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#     (8): ReLU()
#     (9): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (10): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (11): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (12): ReLU()
#     (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (14): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (16): ReLU()
#     (17): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fc_layers): Sequential(
#     (0): Linear(in_features=3200, out_features=4096, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=4096, out_features=1024, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=1024, out_features=5, bias=True)
#   )
# )
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 1: TrL=1.1875, TrA=0.5163, VL=1.0421, VA=0.6096, TeL=1.0692, TeA=0.5848,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 2: TrL=0.9884, TrA=0.6034, VL=0.9170, VA=0.6435, TeL=0.9765, TeA=0.5930,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 3: TrL=0.9039, TrA=0.6376, VL=0.8819, VA=0.6836, TeL=0.9376, TeA=0.6250,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 4: TrL=0.8262, TrA=0.6765, VL=0.8541, VA=0.6740, TeL=0.8910, TeA=0.6562,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 5: TrL=0.7772, TrA=0.6958, VL=0.8537, VA=0.6802, TeL=0.8879, TeA=0.6689,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 6: TrL=0.7351, TrA=0.7191, VL=0.8537, VA=0.6740, TeL=0.9181, TeA=0.6652,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 7: TrL=0.7033, TrA=0.7340, VL=0.8052, VA=0.6929, TeL=0.8853, TeA=0.6585,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 8: TrL=0.6686, TrA=0.7483, VL=0.7365, VA=0.7431, TeL=0.8132, TeA=0.7046,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 9: TrL=0.6371, TrA=0.7540, VL=0.7754, VA=0.7211, TeL=0.8232, TeA=0.7068,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 10: TrL=0.6082, TrA=0.7713, VL=0.7498, VA=0.7226, TeL=0.8363, TeA=0.6860,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 11: TrL=0.5871, TrA=0.7759, VL=0.7643, VA=0.7176, TeL=0.8362, TeA=0.6711,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 12: TrL=0.5506, TrA=0.7899, VL=0.7748, VA=0.7064, TeL=0.8790, TeA=0.6540,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 13: TrL=0.5337, TrA=0.8015, VL=0.6977, VA=0.7527, TeL=0.7787, TeA=0.7121,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 14: TrL=0.5078, TrA=0.8072, VL=0.7972, VA=0.7311, TeL=0.7820, TeA=0.7158,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 15: TrL=0.4595, TrA=0.8271, VL=0.7349, VA=0.7523, TeL=0.8252, TeA=0.6935,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 16: TrL=0.4460, TrA=0.8295, VL=0.8064, VA=0.7415, TeL=0.8548, TeA=0.6860,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 17: TrL=0.4206, TrA=0.8398, VL=0.8073, VA=0.7388, TeL=0.8152, TeA=0.7247,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 18: TrL=0.4003, TrA=0.8534, VL=0.8023, VA=0.7299, TeL=0.8550, TeA=0.7068,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 19: TrL=0.3822, TrA=0.8607, VL=0.7698, VA=0.7400, TeL=0.7771, TeA=0.7262,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 20: TrL=0.3433, TrA=0.8780, VL=0.7034, VA=0.7643, TeL=0.7706, TeA=0.7173,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 21: TrL=0.3153, TrA=0.8860, VL=0.7601, VA=0.7292, TeL=0.8088, TeA=0.7418,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 22: TrL=0.2885, TrA=0.9006, VL=0.7530, VA=0.7585, TeL=0.8315, TeA=0.7046,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 23: TrL=0.2807, TrA=0.8943, VL=0.7413, VA=0.7577, TeL=0.8345, TeA=0.7210,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 24: TrL=0.2526, TrA=0.9036, VL=0.7712, VA=0.7697, TeL=0.8482, TeA=0.7135,
# train:   0%|          | 0/188 [00:00<?, ?it/s]
# val:   0%|          | 0/54 [00:00<?, ?it/s]
# test:   0%|          | 0/28 [00:00<?, ?it/s]
# Epoch 25: TrL=0.2335, TrA=0.9182, VL=0.7695, VA=0.7647, TeL=0.8396, TeA=0.7269,

# %%
#helper function to visualize the data in numpy
def im_convert(tensor):
    image = tensor.numpy()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
    #image = image.clip(0, 1)
    return image

# %%
# transform the images in numpy and see some sample images
import numpy as np

classes = ('daisy', 'dandelion', 'roses', 'sunflowers', 'tulips')

dataiter = iter(validation_loader)
images, labels = dataiter.next()
fig = plt.figure(figsize=(25, 4))
for idx in np.arange(16):
    ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
    plt.imshow(im_convert(images[idx]))
    ax.set_title(classes[labels[idx].item()])

# %%
#Predicting the Category for all Test Images
# Confusion_matrix

total_correct = 0
total_images = 0
confusion_matrix1 = np.zeros([5,5], int)
with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(dev)
        labels = labels.to(dev)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total_images += labels.size(0)
        total_correct += (predicted == labels).sum().item()
        for i, l in enumerate(labels):
            confusion_matrix1[l.item(), predicted[i].item()] += 1 
model_accuracy = total_correct / total_images * 100
print('total images correct {0} on {1} total images with an accuracy of : {2:.2f}%'.format(total_correct,total_images, model_accuracy))
print ()
# Out:
# total images correct 319 on 438 total images with an accuracy of : 72.83%

# %%
#class_wise accuracy
print('{0:5s} : {1}'.format('Category','Accuracy'))
for i, r in enumerate(confusion_matrix1):
    print('{0:5s} : {1:.1f}'.format(classes[i], r[i]/np.sum(r)*100))
# Out:
# Category : Accuracy
# daisy : 74.4
# dandelion : 76.4
# roses : 62.5
# sunflowers : 79.7
# tulips : 71.0

# %%
import pandas as pd
import seaborn as sn
df1  = pd.DataFrame(confusion_matrix1,classes,classes)
sn.set(font_scale=2) # for label size
sn.heatmap(df1, annot=True, annot_kws={"size": 16}, cmap ="YlGnBu") # font size

plt.show()

# %%
def predict_image(img, model):
    # Get predictions from model
    img = (img.unsqueeze(dim=0)).to(dev)
    yb = model(img)
    # Pick index with highest probability
    _, preds  = torch.max(yb, dim=1)
    # Retrieve the class label
    return train_set.classes[preds[0].item()]

# %%
img, label = test_set[139]
plt.imshow(img.permute(1, 2, 0))
print('Label:', train_set.classes[label], ', Predicted:', predict_image(img, model))
# Out:
# Label: dandelion , Predicted: daisy
